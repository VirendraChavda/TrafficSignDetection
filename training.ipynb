# %%
# import torch
# print(torch.backends.cudnn.is_available())  # Should return True
# print(torch.backends.cudnn.version())       # Displays cuDNN version
# Out:
# True
# 90100

# %%
from ultralytics import YOLO

# Load a pretrained YOLO11 segment model
model = YOLO("yolo11n.pt")

# Train the model
results = model.train(data=r"C:\Users\viren\Portfolio\Traffic Sign\data\data.yaml", epochs=50, imgsz=416, device = 'cuda', amp=False)
# Out:
# ...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 6.63MB/s]
# Ultralytics 8.3.31  Python-3.10.10 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# ...

# %%
trained_model = YOLO('runs/detect/train/weights/best.pt')

# %%
test_results = trained_model('data/test/images', save = True)
# Out:
# image 1/897 c:\Users\viren\Portfolio\Traffic Sign\data\test\images\DSCN1324-1-_JPG.rf.e32fa4c48bf40d12460c310139c77648.jpg: 416x416 1 informatory board, 11.1ms
# image 2/897 c:\Users\viren\Portfolio\Traffic Sign\data\test\images\DSCN1733_JPG.rf.84b2d310f609f84eb8f754b7278eb4f7.jpg: 416x416 1 informatory board, 1 overtaking prohibited, 1 stop, 12.0ms
# image 3/897 c:\Users\viren\Portfolio\Traffic Sign\data\test\images\DSCN2026_JPG_jpg.rf.141d2899842d95ac843b2de66680146d.jpg: 416x416 1 informatory board, 16.3ms
# image 4/897 c:\Users\viren\Portfolio\Traffic Sign\data\test\images\DSCN2052_JPG.rf.c52e8a6998d18a6e3188f4463444bd92.jpg: 416x416 1 informatory board, 24.6ms
# image 5/897 c:\Users\viren\Portfolio\Traffic Sign\data\test\images\DSCN2202_JPG.rf.a120302e0fc1ffcd3e80514d8125b428.jpg: 416x416 2 informatory boards, 16.0ms
# image 6/897 c:\Users\viren\Portfolio\Traffic Sign\data\test\images\DSCN2202_JPG_jpg.rf.6e230fb1d2e3dceaed26c0d875c15843.jpg: 416x416 2 informatory boards, 12.1ms
# ...

# %%
test_video_results = trained_model('test_videos', save = True)
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/15 (frame 1/1126) c:\Users\viren\Portfolio\Traffic Sign\test_videos\v1.mp4: 256x416 1 no entry, 75.0ms
# video 1/15 (frame 2/1126) c:\Users\viren\Portfolio\Traffic Sign\test_videos\v1.mp4: 256x416 1 no entry, 14.0ms
# video 1/15 (frame 3/1126) c:\Users\viren\Portfolio\Traffic Sign\test_videos\v1.mp4: 256x416 1 no entry, 22.8ms
# ...
